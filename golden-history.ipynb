# %%
# getting necessary libraries
import plotly.graph_objects as go
import numpy as np
import pandas as pd

iapps_df = pd.read_csv (r'bdor_iapps2.csv')

# %%
iapps_df
# Out:
#                Player  Year  Count
# 0    Stanley Matthews  1934      2
# 1    Stanley Matthews  1935      1
# 2    Stanley Matthews  1937      3
# 3    Stanley Matthews  1938      8
# 4    Stanley Matthews  1939      3
# ..                ...   ...    ...
# 550       Luka Modric  2017      8
# 551       Luka Modric  2018     15
# 552       Luka Modric  2019      9
# 553       Luka Modric  2020      6
# 554       Luka Modric  2021     13
#
# [555 rows x 3 columns]

# %%
player_list = ['Stanley Matthews', 'Alfredo Di Stefano', 'Raymond Kopa', 'Luis Suarez', 'Omar Sivori', 'Josef Masopust', 'Lev Yashin', 'Denis Law', 'Eusebio', 'Bobby Charlton', 'Florian Albert', 'George Best', 'Gianni Rivera', 'Gerd Muller', 'Johan Cruyff', 'Franz Beckenbauer', 'Oleg Blokhin', 'Allan Simonsen', 'Kevin Keegan', 'Karl-Heinz Rummenigge', 'Paolo Rossi', 'Michel Platini', 'Igor Belanov', 'Ruud Gullit', 'Marco van Basten', 'Lothar Matthaus', 'Jean-Pierre Papin', 'Roberto Baggio', 'Hristo Stoichkov', 'George Weah', 'Matthias Sammer', 'Ronaldo', 'Zinedine Zidane', 'Rivaldo', 'Luis Figo', 'Michael Owen', 'Pavel Nedved', 'Andriy Shevchenko', 'Ronaldinho', 'Fabio Cannavaro', 'Kaka', 'Cristiano Ronaldo', 'Lionel Messi', 'Luka Modric']

# %%
# the idea behind this ridgeline plot with Plotly is to add traces manually, each trace corresponding to a particular year's temperature distribution
# thus, we are to store each year's data (temperatures and their respective count) in seperate arrays or pd.series that we store in a dictionnary to retrieve them easily
array_dict = {} # instantiating an empty dictionnary
for Player in player_list:
    array_dict[f'x_{Player}'] = iapps_df[iapps_df['Player']==Player]['Year'] # storing the temperature data for each year
    array_dict[f'y_{Player}'] = iapps_df[iapps_df['Player']==Player]['Count'] # storing the temperature count for each year
    array_dict[f'y_{Player}'] = (array_dict[f'y_{Player}'] - array_dict[f'y_{Player}'].min()) \
                                / (array_dict[f'y_{Player}'].max() - array_dict[f'y_{Player}'].min()) # we normalize the array (min max normalization)

# once all of this is done, we can create a plotly.graph_objects.Figure and add traces with fig.add_trace() method
# since we have stored the temperatures and their respective count for each year, we can plot scatterplots (go.Scatter)
# we thus iterate over year_list and create a 'blank line' that is placed at y = index, then the corresponding temperature count line
fig = go.Figure()
for index, Player in enumerate(player_list):
    fig.add_trace(go.Scatter(
                            x=[1930, 2021], y=np.full(2, len(player_list)-index),
                            mode='lines',
                            line_color='white'))
    
    fig.add_trace(go.Scatter(
                            x=array_dict[f'x_{Player}'],
                            y=array_dict[f'y_{Player}'] + (len(player_list)-index) + 0.4,
                           # fill='tonexty',
        mode='lines',
                            name=f'{Player}'))
    
    # plotly.graph_objects' way of adding text to a figure
    fig.add_annotation(
                        x=-20,
                        y=len(player_list)-index,
                        text=f'{Player}',
                        showarrow=False,
                        yshift=10)
    
    fig.update_xaxes(range=[1930, 2021])


# here you can modify the figure and the legend titles
fig.update_layout(
                title='Ballon Dor Winners: International Appearances',
                showlegend=False,
                xaxis=dict(title='Year'),
                yaxis=dict(showticklabels=False) # that way you hide the y axis ticks labels
                )

fig.show()
# Out:
# <div>                            <div id="7a297f64-6894-48d2-b2a1-7f4399176426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a297f64-6894-48d2-b2a1-7f4399176426")) {                    Plotly.newPlot(                        "7a297f64-6894-48d2-b2a1-7f4399176426",                        [{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[44,44],"type":"scatter"},{"mode":"lines","name":"Stanley Matthews","x":[1934,1935,1937,1938,1939,1947,1948,1949,1950,1951,1953,1954,1955,1956,1957],"y":[44.542857142857144,44.4,44.68571428571428,45.4,44.68571428571428,45.114285714285714,45.114285714285714,44.4,44.542857142857144,44.4,44.68571428571428,44.97142857142857,44.97142857142857,44.97142857142857,44.68571428571428],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[43,43],"type":"scatter"},{"mode":"lines","name":"Alfredo Di Stefano","x":[1947,1957,1958,1959,1960,1961],"y":[43.9,44.15,43.4,43.65,44.4,44.15],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[42,42],"type":"scatter"},{"mode":"lines","name":"Raymond Kopa","x":[1952,1953,1954,1955,1956,1958,1959,1960,1961,1962],"y":[43.06666666666666,43.233333333333334,43.233333333333334,43.233333333333334,42.4,43.4,42.9,42.733333333333334,42.733333333333334,42.9],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[41,41],"type":"scatter"},{"mode":"lines","name":"Luis Suarez","x":[1957,1958,1959,1960,1961,1962,1963,1964,1965,1966],"y":[42.233333333333334,41.733333333333334,42.06666666666666,42.4,41.4,41.56666666666666,41.4,41.56666666666666,41.56666666666666,41.56666666666666],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[40,40],"type":"scatter"},{"mode":"lines","name":"Omar Sivori","x":[1956,1957,1961,1962],"y":[41.4,40.62222222222222,40.51111111111111,40.4],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[39,39],"type":"scatter"},{"mode":"lines","name":"Josef Masopust","x":[1954,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966],"y":[39.4,40.3,39.9,40.3,39.5,39.9,40.0,40.4,39.699999999999996,39.699999999999996,39.4,39.4],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[38,38],"type":"scatter"},{"mode":"lines","name":"Lev Yashin","x":[1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967],"y":[38.4,38.65,39.4,38.775,38.9,38.4,38.775,38.775,39.025,38.65,39.025,38.775,39.025,38.775],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[37,37],"type":"scatter"},{"mode":"lines","name":"Denis Law","x":[1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1972,1973,1974],"y":[37.56666666666666,37.9,37.9,37.733333333333334,37.733333333333334,38.4,38.06666666666666,38.233333333333334,37.56666666666666,37.733333333333334,37.4,37.56666666666666,38.4,37.733333333333334,37.733333333333334],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[36,36],"type":"scatter"},{"mode":"lines","name":"Eusebio","x":[1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973],"y":[36.49090909090909,36.763636363636365,36.4,36.85454545454545,36.945454545454545,37.4,36.85454545454545,36.49090909090909,36.67272727272727,36.4,36.763636363636365,37.127272727272725,36.67272727272727],"type":"scatter"},{"line":{"color":"white"},"mode":"lines","x":[1930,2021],"y":[35,35],"type":"scatter"},{"mode":"lines","name":"Bobby Charlton","x":[1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970],"y":[35.58181818181818,35.67272727272727,35.763636363636365,35.85454545454545,35.763636363636365,35.945454545454545,35.763636363636365,35.49090909090909,36.4,35.4,35.763636363636365,35.85454545454545,35.85454545454545] ...
